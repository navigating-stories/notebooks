# %% [markdown]
# # Scrape Stories from Story Center
#
# Scrape English Corona stories from the Story Center website: https://www.storycenter.org/covid-stories.
#
# The stories are stored in dictionaries with the following fields:
#
# - `link`: The link of the story page (string)
# - `title`: The title of the story page (string)
# - `summary`: A short summary of the story displayed on the main page (string)
# - `date_published`: The date when the story was published (string)
# - `date_modified`: The date when the story was last modified (string)
# - `author`: The author of the story (string)
# - `location`: The location of the author (string)
# - `story_text`: The text of the story (string)
#
# The web pages containing the stories are stored as `.html`. The notebook requires a folder at `DATA_DIR`.

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os

# %%
# Set URL of the main page containing the links to the story pages

URL = "https://www.storycenter.org/covid-stories"

# Set directory for storing web pages

DATA_DIR = "../storycenter.org/scraped/"

# %%
# Function to check if directory for saving web page exists

def check_dir(DATA_DIR):
    if not os.path.isdir(DATA_DIR):
        os.makedirs(DATA_DIR)
        print(f"Created saving directory at {DATA_DIR}")

# %%
# Function to check if web page can be loaded from disk; otherwise fetch website and save as .html to disk

def load_web_page(URL, file_name, DATA_DIR):
    check_dir(DATA_DIR)
    if os.path.exists(file_name):
        page = open(file_name, "r", encoding="utf-8").read()
        print(f"Loaded web page from {file_name}")
    else:
        req = Request(URL, headers = {"User-Agent": "Mozilla/5.0"})
        page = urlopen(req).read()
        with open(file_name, "w", encoding="utf-8") as file:
            file.write(page.decode())
        print(f"Saved web page to {file_name}")
    return page

# %%
# Function to extract links to the story pages from main page

def extract_hrefs_from_url(URL):
    main_page = BeautifulSoup(urlopen(URL).read(), "html.parser")
    
    hrefs = []

    for instance in main_page.find_all("a", attrs = {"class": "summary-thumbnail-container sqs-gallery-image-container"}):
        new_link = instance.get("href")
        hrefs.append("https://www.storycenter.org" + new_link)
        print("Extracted link: {}".format(hrefs[-1]))
    
    return hrefs

# %%
# Function to extract text from story pages

def extract_text_from_url(URL):
    new_file_name = DATA_DIR + URL.split("//")[-1] + ".html"
    new_page = BeautifulSoup(load_web_page(URL, new_file_name, DATA_DIR), "html.parser")
    new_title = new_page.title.string[:new_page.title.string.find(" —")]
    new_summary = new_page.find("meta", attrs = {"itemprop": "description"}).get("content")
    new_date_pub = new_page.find("meta", attrs = {"itemprop": "datePublished"}).get("content")
    new_date_mod = new_page.find("meta", attrs = {"itemprop": "dateModified"}).get("content")
    new_inline_text = new_page.find("div", attrs = {"class": "sqs-layout sqs-grid-12 columns-12"})
    new_stripped_text = [text.replace("\xa0", " ") for text in new_inline_text.stripped_strings]
    new_first_line = new_stripped_text[0].split(" ")
    new_author = "".join([s + " " for s in new_first_line[1:3]])
    new_location = "".join([s + " " for s in new_first_line[3:]])
    new_story_text = "\n".join(new_stripped_text[1:])
    new_doc = {
        "link": URL,
        "title": new_title,
        "summary": new_summary,
        "date_published": new_date_pub,
        "date_modified": new_date_mod,
        "author": new_author,
        "location": new_location,
        "story_text": new_story_text
    }
    print("Extracted text from: {}".format(URL))
    
    return new_doc

# %%
# Wrapper to for list of story pages

def extract_texts_from_url_list(URL_list):
    docs = []
    for URL in URL_list:
        docs.append(extract_text_from_url(URL))
    
    print("Done")
    
    return docs

# %%
# Function to print doc

def print_doc(doc):
    for field in doc.keys():
        if isinstance(doc[field], list):
            print(field + ": " + "".join([s + "\n" + "\t" for s in doc[field]]) + "\n")
        else:
            print(field + ": " + doc[field] + "\n")
        
    return

# %%
# Extract links from main page

hrefs = extract_hrefs_from_url(URL)
# Out:
# Extracted link: https://www.storycenter.org/covid-stories-1//thirty-three-days
# Extracted link: https://www.storycenter.org/covid-stories-1//spains-rainbows-of-hope
# Extracted link: https://www.storycenter.org/covid-stories-1//funeral-for-our-dead-beliefs
# Extracted link: https://www.storycenter.org/covid-stories-1//diary-of-a-queer-woman-during-covid-19-pandemic
# Extracted link: https://www.storycenter.org/covid-stories-1//the-year-of-the-rat
# Extracted link: https://www.storycenter.org/covid-stories-1//finding-hope-in-the-little-things
# Extracted link: https://www.storycenter.org/covid-stories-1//a-ma
# Extracted link: https://www.storycenter.org/covid-stories-1//broad-beans-on-the-wall
# Extracted link: https://www.storycenter.org/covid-stories-1//what-is-it-like-to-be-you
# Extracted link: https://www.storycenter.org/covid-stories-1//dear-coronavirus
# Extracted link: https://www.storycenter.org/covid-stories-1//ive-found-my-marbles
# Extracted link: https://www.storycenter.org/covid-stories-1//good-thing-it-was-my-shift-that-night
# Extracted link: https://www.storycenter.org/covid-stories-1//a-thousand-times-a-day
# Extracted link: https://www.storycenter.org/covid-stories-1//two-at-once
# Extracted link: https://www.storycenter.org/covid-stories-1//hydroxychloroquine
# Extracted link: https://www.storycenter.org/covid-stories-1//the-brokenness-of-quarantine-isolation
# Extracted link: https://www.storycenter.org/covid-stories-1//definitely-my-new-normal
# Extracted link: https://www.storycenter.org/covid-stories-1//a-call-that-keeps-me-grounded
# Extracted link: https://www.storycenter.org/covid-stories-1//tuesdays-at-2
# Extracted link: https://www.storycenter.org/covid-stories-1//at-home
# Extracted link: https://www.storycenter.org/covid-stories-1//nighttime-gratitude-19-april
# Extracted link: https://www.storycenter.org/covid-stories-1//my-purpose-during-a-pandemic
# Extracted link: https://www.storycenter.org/covid-stories-1//breaking-things
# Extracted link: https://www.storycenter.org/covid-stories-1//william-grange
# Extracted link: https://www.storycenter.org/covid-stories-1//the-metropolis-men
# Extracted link: https://www.storycenter.org/covid-stories-1//wvoysvuleyw3obwix8zx0lmyp436tx
# Extracted link: https://www.storycenter.org/covid-stories-1//lifelines
# Extracted link: https://www.storycenter.org/covid-stories-1//day-fourteen-03312020nbsp
# Extracted link: https://www.storycenter.org/covid-stories-1//small-town-america-has-a-heart
# Extracted link: https://www.storycenter.org/covid-stories-1//we-rise-by-lifting-others
# Extracted link: https://www.storycenter.org/covid-stories-1//flight-attendants-on-the-covid-19-frontline
# Extracted link: https://www.storycenter.org/covid-stories-1//babys-breath
# Extracted link: https://www.storycenter.org/covid-stories-1//reflections-of-a-library-mom
# Extracted link: https://www.storycenter.org/covid-stories-1//8-pm-applause-for-spain
# Extracted link: https://www.storycenter.org/covid-stories-1//musings-of-an-entrepreneur-during-covid-19
# Extracted link: https://www.storycenter.org/covid-stories-1//a-busy-mind-quieted-by-collective-clang-and-clatter
# Extracted link: https://www.storycenter.org/covid-stories-1//in-body-or-spirit
# Extracted link: https://www.storycenter.org/covid-stories-1//passing-through
# Extracted link: https://www.storycenter.org/covid-stories-1//blessed
# Extracted link: https://www.storycenter.org/covid-stories-1//a-work-in-progress
# Extracted link: https://www.storycenter.org/covid-stories-1//feeling-lucky
# Extracted link: https://www.storycenter.org/covid-stories-1//unheard-and-not-understood
# Extracted link: https://www.storycenter.org/covid-stories-1//a-poets-journey-into-self
# Extracted link: https://www.storycenter.org/covid-stories-1//listening-is-so-important-but-we-never-do
# Extracted link: https://www.storycenter.org/covid-stories-1//scarcity-vs-abundance
# Extracted link: https://www.storycenter.org/covid-stories-1//puzzle-pandemic
# Extracted link: https://www.storycenter.org/covid-stories-1//the-sum-of-it-all
# Extracted link: https://www.storycenter.org/covid-stories-1//i-really-hope-to-see-things-getting-better-soon
# Extracted link: https://www.storycenter.org/covid-stories-1//family-support
# Extracted link: https://www.storycenter.org/covid-stories-1//flight-cancelled
# Extracted link: https://www.storycenter.org/covid-stories-1//that-one-beautiful-moment
# Extracted link: https://www.storycenter.org/covid-stories-1//panda-excess
# Extracted link: https://www.storycenter.org/covid-stories-1//simple-acts
# Extracted link: https://www.storycenter.org/covid-stories-1//vanya
# Extracted link: https://www.storycenter.org/covid-stories-1//distancing-becoming
# Extracted link: https://www.storycenter.org/covid-stories-1//pause
# Extracted link: https://www.storycenter.org/covid-stories-1//luxury-of-a-funeral
# Extracted link: https://www.storycenter.org/covid-stories-1//disconnected-unattached
# Extracted link: https://www.storycenter.org/covid-stories-1//a-gift-in-the-time-of-covid
# Extracted link: https://www.storycenter.org/covid-stories-1//my-family-my-safe-space
# Extracted link: https://www.storycenter.org/covid-stories-1//the-sound-from-the-past
# Extracted link: https://www.storycenter.org/covid-stories-1//a-tour-of-world-airports-during-the-covid-19-pandemic
# Extracted link: https://www.storycenter.org/covid-stories-1//phone
# Extracted link: https://www.storycenter.org/covid-stories-1//grass-is-always-greener-on-the-other-side
# Extracted link: https://www.storycenter.org/covid-stories-1//to-plant-in-a-time-of-isolation
# Extracted link: https://www.storycenter.org/covid-stories-1//better-days
# Extracted link: https://www.storycenter.org/covid-stories-1//my-walls-almost-tipped-over
# Extracted link: https://www.storycenter.org/covid-stories-1//pandemic-road-trip
# Extracted link: https://www.storycenter.org/covid-stories-1//the-other-residents
# Extracted link: https://www.storycenter.org/covid-stories-1//saving-smiles
# Extracted link: https://www.storycenter.org/covid-stories-1//omar-a-special-kind-of-brother
# Extracted link: https://www.storycenter.org/covid-stories-1//shifts
# Extracted link: https://www.storycenter.org/covid-stories-1//my-covid19-life-in-may-2020
# Extracted link: https://www.storycenter.org/covid-stories-1//time-and-space-are-out-of-joint
# Extracted link: https://www.storycenter.org/covid-stories-1//the-irony-of-life
# Extracted link: https://www.storycenter.org/covid-stories-1//from-historical-pageant-to-zooming-tai-chi
# Extracted link: https://www.storycenter.org/covid-stories-1//grateful-life
# Extracted link: https://www.storycenter.org/covid-stories-1//light-at-the-end-of-the-tunnel
# Extracted link: https://www.storycenter.org/covid-stories-1//red-shoes
# Extracted link: https://www.storycenter.org/covid-stories-1//a-new-friend
# Extracted link: https://www.storycenter.org/covid-stories-1//pain-in-times-of-covid-19
# Extracted link: https://www.storycenter.org/covid-stories-1//a-year-of-mourning
# Extracted link: https://www.storycenter.org/covid-stories-1//the-winter-storm
# Extracted link: https://www.storycenter.org/covid-stories-1//the-bottle-garden
# Extracted link: https://www.storycenter.org/covid-stories-1//back-from-the-dead
# Extracted link: https://www.storycenter.org/covid-stories-1//piato
# Extracted link: https://www.storycenter.org/covid-stories-1//yes-i-do-know-it
# Extracted link: https://www.storycenter.org/covid-stories-1//my-charlie-brown-christmas
# Extracted link: https://www.storycenter.org/covid-stories-1//the-grey-cat
# Extracted link: https://www.storycenter.org/covid-stories-1//difficult-choices
# Extracted link: https://www.storycenter.org/covid-stories-1//three-hundred-pages
# Extracted link: https://www.storycenter.org/covid-stories-1//water-on-concrete
# Extracted link: https://www.storycenter.org/covid-stories-1//living-with-the-virus
# Extracted link: https://www.storycenter.org/covid-stories-1//upstairs-neighbor
# Extracted link: https://www.storycenter.org/covid-stories-1//im-not-scared-but-she-was
# Extracted link: https://www.storycenter.org/covid-stories-1//a-glowing-story-tower
# Extracted link: https://www.storycenter.org/covid-stories-1//questioning-friendships-during-covid-19
# Extracted link: https://www.storycenter.org/covid-stories-1//could-i-have-done-more
# Extracted link: https://www.storycenter.org/covid-stories-1//grateful
# Extracted link: https://www.storycenter.org/covid-stories-1//waiting-for-sunrise
# Extracted link: https://www.storycenter.org/covid-stories-1//covid-doldrums-or-how-i-learned-to-be-happy-and-sad-at-the-same-time
# Extracted link: https://www.storycenter.org/covid-stories-1//sea-of-signals
# Extracted link: https://www.storycenter.org/covid-stories-1//where-the-fig-falls
# Extracted link: https://www.storycenter.org/covid-stories-1//how-quickly-everything-changed
# Extracted link: https://www.storycenter.org/covid-stories-1//changing-jobs-during-a-pandemic
# Extracted link: https://www.storycenter.org/covid-stories-1//a-rabbit-for-us-all
# Extracted link: https://www.storycenter.org/covid-stories-1//heaven-and-hell
# Extracted link: https://www.storycenter.org/covid-stories-1//stuck-inside-myself
# Extracted link: https://www.storycenter.org/covid-stories-1//be-valiant
# Extracted link: https://www.storycenter.org/covid-stories-1//smooth-sailing
# Extracted link: https://www.storycenter.org/covid-stories-1//being-postive
# Extracted link: https://www.storycenter.org/covid-stories-1//finally-free
# Extracted link: https://www.storycenter.org/covid-stories-1//lockdown-a-mother-working-from-home
# Extracted link: https://www.storycenter.org/covid-stories-1//freedom-in-a-cage
# Extracted link: https://www.storycenter.org/covid-stories-1//how-are-you
# Extracted link: https://www.storycenter.org/covid-stories-1//walking-in-the-zelienople-woods
# Extracted link: https://www.storycenter.org/covid-stories-1//running-to-normalcy
# Extracted link: https://www.storycenter.org/covid-stories-1//andre-my-older-little-sister
# Extracted link: https://www.storycenter.org/covid-stories-1//new-girl-in-town
# Extracted link: https://www.storycenter.org/covid-stories-1//lost-and-found
# Extracted link: https://www.storycenter.org/covid-stories-1//you-can-stay-longer-
# Extracted link: https://www.storycenter.org/covid-stories-1//immunocompromised

# %%
# Extract texts from links

docs = extract_texts_from_url_list(hrefs)
# Out:
# Loaded web page from ../storycenter.org/scraped/thirty-three-days.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//thirty-three-days
# Loaded web page from ../storycenter.org/scraped/spains-rainbows-of-hope.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//spains-rainbows-of-hope
# Loaded web page from ../storycenter.org/scraped/funeral-for-our-dead-beliefs.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//funeral-for-our-dead-beliefs
# Loaded web page from ../storycenter.org/scraped/diary-of-a-queer-woman-during-covid-19-pandemic.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//diary-of-a-queer-woman-during-covid-19-pandemic
# Loaded web page from ../storycenter.org/scraped/the-year-of-the-rat.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//the-year-of-the-rat
# Loaded web page from ../storycenter.org/scraped/finding-hope-in-the-little-things.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//finding-hope-in-the-little-things
# Loaded web page from ../storycenter.org/scraped/a-ma.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//a-ma
# Loaded web page from ../storycenter.org/scraped/broad-beans-on-the-wall.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//broad-beans-on-the-wall
# Loaded web page from ../storycenter.org/scraped/what-is-it-like-to-be-you.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//what-is-it-like-to-be-you
# Loaded web page from ../storycenter.org/scraped/dear-coronavirus.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//dear-coronavirus
# Loaded web page from ../storycenter.org/scraped/ive-found-my-marbles.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//ive-found-my-marbles
# Loaded web page from ../storycenter.org/scraped/good-thing-it-was-my-shift-that-night.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//good-thing-it-was-my-shift-that-night
# Loaded web page from ../storycenter.org/scraped/a-thousand-times-a-day.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//a-thousand-times-a-day
# Loaded web page from ../storycenter.org/scraped/two-at-once.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//two-at-once
# Loaded web page from ../storycenter.org/scraped/hydroxychloroquine.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//hydroxychloroquine
# Loaded web page from ../storycenter.org/scraped/the-brokenness-of-quarantine-isolation.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//the-brokenness-of-quarantine-isolation
# Loaded web page from ../storycenter.org/scraped/definitely-my-new-normal.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//definitely-my-new-normal
# Loaded web page from ../storycenter.org/scraped/a-call-that-keeps-me-grounded.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//a-call-that-keeps-me-grounded
# Loaded web page from ../storycenter.org/scraped/tuesdays-at-2.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//tuesdays-at-2
# Loaded web page from ../storycenter.org/scraped/at-home.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//at-home
# Loaded web page from ../storycenter.org/scraped/nighttime-gratitude-19-april.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//nighttime-gratitude-19-april
# Loaded web page from ../storycenter.org/scraped/my-purpose-during-a-pandemic.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//my-purpose-during-a-pandemic
# Loaded web page from ../storycenter.org/scraped/breaking-things.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//breaking-things
# Loaded web page from ../storycenter.org/scraped/william-grange.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//william-grange
# Loaded web page from ../storycenter.org/scraped/the-metropolis-men.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//the-metropolis-men
# Loaded web page from ../storycenter.org/scraped/wvoysvuleyw3obwix8zx0lmyp436tx.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//wvoysvuleyw3obwix8zx0lmyp436tx
# Loaded web page from ../storycenter.org/scraped/lifelines.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//lifelines
# Loaded web page from ../storycenter.org/scraped/day-fourteen-03312020nbsp.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//day-fourteen-03312020nbsp
# Loaded web page from ../storycenter.org/scraped/small-town-america-has-a-heart.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//small-town-america-has-a-heart
# Loaded web page from ../storycenter.org/scraped/we-rise-by-lifting-others.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//we-rise-by-lifting-others
# Loaded web page from ../storycenter.org/scraped/flight-attendants-on-the-covid-19-frontline.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//flight-attendants-on-the-covid-19-frontline
# Loaded web page from ../storycenter.org/scraped/babys-breath.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//babys-breath
# Loaded web page from ../storycenter.org/scraped/reflections-of-a-library-mom.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//reflections-of-a-library-mom
# Loaded web page from ../storycenter.org/scraped/8-pm-applause-for-spain.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//8-pm-applause-for-spain
# Loaded web page from ../storycenter.org/scraped/musings-of-an-entrepreneur-during-covid-19.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//musings-of-an-entrepreneur-during-covid-19
# Loaded web page from ../storycenter.org/scraped/a-busy-mind-quieted-by-collective-clang-and-clatter.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//a-busy-mind-quieted-by-collective-clang-and-clatter
# Loaded web page from ../storycenter.org/scraped/in-body-or-spirit.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//in-body-or-spirit
# Loaded web page from ../storycenter.org/scraped/passing-through.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//passing-through
# Loaded web page from ../storycenter.org/scraped/blessed.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//blessed
# Loaded web page from ../storycenter.org/scraped/a-work-in-progress.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//a-work-in-progress
# Loaded web page from ../storycenter.org/scraped/feeling-lucky.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//feeling-lucky
# Loaded web page from ../storycenter.org/scraped/unheard-and-not-understood.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//unheard-and-not-understood
# Loaded web page from ../storycenter.org/scraped/a-poets-journey-into-self.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//a-poets-journey-into-self
# Loaded web page from ../storycenter.org/scraped/listening-is-so-important-but-we-never-do.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//listening-is-so-important-but-we-never-do
# Loaded web page from ../storycenter.org/scraped/scarcity-vs-abundance.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//scarcity-vs-abundance
# Loaded web page from ../storycenter.org/scraped/puzzle-pandemic.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//puzzle-pandemic
# Loaded web page from ../storycenter.org/scraped/the-sum-of-it-all.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//the-sum-of-it-all
# Loaded web page from ../storycenter.org/scraped/i-really-hope-to-see-things-getting-better-soon.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//i-really-hope-to-see-things-getting-better-soon
# Loaded web page from ../storycenter.org/scraped/family-support.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//family-support
# Loaded web page from ../storycenter.org/scraped/flight-cancelled.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//flight-cancelled
# Loaded web page from ../storycenter.org/scraped/that-one-beautiful-moment.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//that-one-beautiful-moment
# Loaded web page from ../storycenter.org/scraped/panda-excess.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//panda-excess
# Loaded web page from ../storycenter.org/scraped/simple-acts.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//simple-acts
# Loaded web page from ../storycenter.org/scraped/vanya.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//vanya
# Loaded web page from ../storycenter.org/scraped/distancing-becoming.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//distancing-becoming
# Loaded web page from ../storycenter.org/scraped/pause.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//pause
# Loaded web page from ../storycenter.org/scraped/luxury-of-a-funeral.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//luxury-of-a-funeral
# Loaded web page from ../storycenter.org/scraped/disconnected-unattached.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//disconnected-unattached
# Loaded web page from ../storycenter.org/scraped/a-gift-in-the-time-of-covid.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//a-gift-in-the-time-of-covid
# Loaded web page from ../storycenter.org/scraped/my-family-my-safe-space.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//my-family-my-safe-space
# Loaded web page from ../storycenter.org/scraped/the-sound-from-the-past.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//the-sound-from-the-past
# Loaded web page from ../storycenter.org/scraped/a-tour-of-world-airports-during-the-covid-19-pandemic.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//a-tour-of-world-airports-during-the-covid-19-pandemic
# Loaded web page from ../storycenter.org/scraped/phone.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//phone
# Loaded web page from ../storycenter.org/scraped/grass-is-always-greener-on-the-other-side.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//grass-is-always-greener-on-the-other-side
# Loaded web page from ../storycenter.org/scraped/to-plant-in-a-time-of-isolation.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//to-plant-in-a-time-of-isolation
# Loaded web page from ../storycenter.org/scraped/better-days.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//better-days
# Loaded web page from ../storycenter.org/scraped/my-walls-almost-tipped-over.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//my-walls-almost-tipped-over
# Loaded web page from ../storycenter.org/scraped/pandemic-road-trip.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//pandemic-road-trip
# Loaded web page from ../storycenter.org/scraped/the-other-residents.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//the-other-residents
# Loaded web page from ../storycenter.org/scraped/saving-smiles.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//saving-smiles
# Loaded web page from ../storycenter.org/scraped/omar-a-special-kind-of-brother.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//omar-a-special-kind-of-brother
# Loaded web page from ../storycenter.org/scraped/shifts.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//shifts
# Loaded web page from ../storycenter.org/scraped/my-covid19-life-in-may-2020.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//my-covid19-life-in-may-2020
# Loaded web page from ../storycenter.org/scraped/time-and-space-are-out-of-joint.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//time-and-space-are-out-of-joint
# Loaded web page from ../storycenter.org/scraped/the-irony-of-life.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//the-irony-of-life
# Loaded web page from ../storycenter.org/scraped/from-historical-pageant-to-zooming-tai-chi.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//from-historical-pageant-to-zooming-tai-chi
# Loaded web page from ../storycenter.org/scraped/grateful-life.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//grateful-life
# Loaded web page from ../storycenter.org/scraped/light-at-the-end-of-the-tunnel.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//light-at-the-end-of-the-tunnel
# Loaded web page from ../storycenter.org/scraped/red-shoes.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//red-shoes
# Loaded web page from ../storycenter.org/scraped/a-new-friend.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//a-new-friend
# Loaded web page from ../storycenter.org/scraped/pain-in-times-of-covid-19.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//pain-in-times-of-covid-19
# Loaded web page from ../storycenter.org/scraped/a-year-of-mourning.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//a-year-of-mourning
# Loaded web page from ../storycenter.org/scraped/the-winter-storm.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//the-winter-storm
# Loaded web page from ../storycenter.org/scraped/the-bottle-garden.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//the-bottle-garden
# Loaded web page from ../storycenter.org/scraped/back-from-the-dead.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//back-from-the-dead
# Loaded web page from ../storycenter.org/scraped/piato.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//piato
# Loaded web page from ../storycenter.org/scraped/yes-i-do-know-it.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//yes-i-do-know-it
# Loaded web page from ../storycenter.org/scraped/my-charlie-brown-christmas.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//my-charlie-brown-christmas
# Loaded web page from ../storycenter.org/scraped/the-grey-cat.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//the-grey-cat
# Loaded web page from ../storycenter.org/scraped/difficult-choices.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//difficult-choices
# Loaded web page from ../storycenter.org/scraped/three-hundred-pages.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//three-hundred-pages
# Loaded web page from ../storycenter.org/scraped/water-on-concrete.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//water-on-concrete
# Loaded web page from ../storycenter.org/scraped/living-with-the-virus.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//living-with-the-virus
# Loaded web page from ../storycenter.org/scraped/upstairs-neighbor.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//upstairs-neighbor
# Loaded web page from ../storycenter.org/scraped/im-not-scared-but-she-was.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//im-not-scared-but-she-was
# Loaded web page from ../storycenter.org/scraped/a-glowing-story-tower.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//a-glowing-story-tower
# Loaded web page from ../storycenter.org/scraped/questioning-friendships-during-covid-19.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//questioning-friendships-during-covid-19
# Loaded web page from ../storycenter.org/scraped/could-i-have-done-more.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//could-i-have-done-more
# Loaded web page from ../storycenter.org/scraped/grateful.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//grateful
# Loaded web page from ../storycenter.org/scraped/waiting-for-sunrise.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//waiting-for-sunrise
# Loaded web page from ../storycenter.org/scraped/covid-doldrums-or-how-i-learned-to-be-happy-and-sad-at-the-same-time.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//covid-doldrums-or-how-i-learned-to-be-happy-and-sad-at-the-same-time
# Loaded web page from ../storycenter.org/scraped/sea-of-signals.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//sea-of-signals
# Loaded web page from ../storycenter.org/scraped/where-the-fig-falls.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//where-the-fig-falls
# Loaded web page from ../storycenter.org/scraped/how-quickly-everything-changed.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//how-quickly-everything-changed
# Loaded web page from ../storycenter.org/scraped/changing-jobs-during-a-pandemic.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//changing-jobs-during-a-pandemic
# Loaded web page from ../storycenter.org/scraped/a-rabbit-for-us-all.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//a-rabbit-for-us-all
# Loaded web page from ../storycenter.org/scraped/heaven-and-hell.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//heaven-and-hell
# Loaded web page from ../storycenter.org/scraped/stuck-inside-myself.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//stuck-inside-myself
# Loaded web page from ../storycenter.org/scraped/be-valiant.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//be-valiant
# Loaded web page from ../storycenter.org/scraped/smooth-sailing.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//smooth-sailing
# Loaded web page from ../storycenter.org/scraped/being-postive.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//being-postive
# Loaded web page from ../storycenter.org/scraped/finally-free.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//finally-free
# Loaded web page from ../storycenter.org/scraped/lockdown-a-mother-working-from-home.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//lockdown-a-mother-working-from-home
# Loaded web page from ../storycenter.org/scraped/freedom-in-a-cage.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//freedom-in-a-cage
# Loaded web page from ../storycenter.org/scraped/how-are-you.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//how-are-you
# Loaded web page from ../storycenter.org/scraped/walking-in-the-zelienople-woods.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//walking-in-the-zelienople-woods
# Loaded web page from ../storycenter.org/scraped/running-to-normalcy.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//running-to-normalcy
# Loaded web page from ../storycenter.org/scraped/andre-my-older-little-sister.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//andre-my-older-little-sister
# Loaded web page from ../storycenter.org/scraped/new-girl-in-town.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//new-girl-in-town
# Loaded web page from ../storycenter.org/scraped/lost-and-found.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//lost-and-found
# Loaded web page from ../storycenter.org/scraped/you-can-stay-longer-.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//you-can-stay-longer-
# Loaded web page from ../storycenter.org/scraped/immunocompromised.html
# Extracted text from: https://www.storycenter.org/covid-stories-1//immunocompromised
# Done

# %%
# Show example doc

print_doc(docs[0])
# Out:
# link: https://www.storycenter.org/covid-stories-1//thirty-three-days
#
# title: Thirty-Three Days
#
# summary: Our baby sister, Sherill, has been rushed to the hospital. As her legal guardian, I immediately think to go there. Debbie reminds me, “Freda, we can’t go there.” Right, no one is allowed! The hospital is restricting visitors.
#
# date_published: 2020-06-03T18:25:13-0700
#
# date_modified: 2021-01-21T14:45:07-0800
#
# author: Alfreda Harris,
#
# location: Flynt, Michigan, U.S.
#
# story_text: I am sheltering in place alone, but not lonely. I miss my Mama. She passed on Friday, January 24, 2020, after five weeks in the hospital. Besides being my mother, she was my housemate and best friend. The eldest of her six children (two boys and four girls), I am her next of kin. I am the one everyone looked to when it came to making decisions. I am the facilitator and advocate on behalf of our family. Now, walking through the house we shared and where I grew up, her presence is all around me. I hear her voice and see her everywhere. Mama left me with many wonderful, sunshine memories. As I grieve her, I am sheltering in place alone, but not lonely.
# Then, on April 5th, a Sunday afternoon, I get a call from my number two sister, Debbie. Our baby sister, Sherill, has been rushed to the hospital. As her legal guardian, I immediately think to go there. Debbie reminds me, “Freda, we can’t go there.” Right, no one is allowed! The hospital is restricting visitors. Sherill lives in a skilled nursing facility, and we have not seen her since March 11th. She has never gone to the hospital alone, without family. We have always been there to support her in navigating through her healthcare concerns. She has many underlying conditions: diabetes, lupus, missing a spleen, high blood pressure, and blindness (caused by diabetic retinopathy).
# Sherill is diagnosed with COVID-19 and placed in an intensive care unit (ICU).
# This begins a “new normal” of caring for my sister from afar. First, I fight for 24 hours to change her “do not resuscitate” code status. Her paperwork showing me as her legal guardian has not been sent with her. When she arrives at the hospital “nonresponsive,” she is asked if she wants to be incubated, if necessary. According to the emergency room attendants, she said, “No.” I was livid, yet victory comes when her code status is changed to resuscitate. That same night, I am asked for permission to incubate her. I say, “Yes.” This is the first of many requests I grant on Sherill’s journey towards surviving COVID-19. There’s victory in every step.
# My days begin with me calling the hospital for an update report from the night nurse. In the early evening, I call to speak with the day nurse before that shift changes. Then, I text my family members to update them on Sherill. I advocate for her, remembering my promise to Mama that we would take care of Sherill. No matter what the report, I look for something that will encourage my family. As the family matriarch, I resolve to be strong for them. Each day, with every step forward on the journey to healing and restoration, I count as another victory.
# I learn so much about different medical terms and procedures. The pulmonologist declares, “Your sister is young. I am not leaving any stone unturned.” The nurses and doctors exemplify the best of care and empathy for patients when their families cannot be with them. The many dedicated healthcare professionals wear multiple hats. We have telephone calls and Zoom meetings with Sherill where we speak life, love, and prayers into her ears. Each day she is still with us we count as a victory.
# Finally, on a Friday, May 8th, Sherill leaves the ICU. Within the hospital setting is a long-term facility just 50 feet away. There she will be supported in weening from the ventilator. Thirty-three days later, Sherill is still here. We count it as a victory!
